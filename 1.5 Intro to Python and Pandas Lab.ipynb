# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
#    Where:
#         My information comes from the Brain Stroke Dataset.
#
#    How:
#         There is no validation on how any of this information was collected as Brainstroke csv was a copy of someone else work. The origonal seems to have gotten the infromation from McKinsey Analytics Online Hackathon - Healthcare Analytics  https://www.kaggle.com/datasets/zzettrkalpakbal/full-filled-brain-stroke-dataset
#
#    What:
#         Features include Gender, Age, Diseases, Married, Work, Residence, glucose, bmi, smoking, stroke
#
#    Why:
#         My father had a stroke and I am working towards biomedical engineering to possibly help others who have had strokes. I have even built a BCI device.
#
# 3. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#    Is a gender more prone to strokes?
#    Does age affect stroke levels?
#    Does BMI affect stroke levels?
#    Does gluecose affect stroke levels?
#    Does smoking affect stroke levels?
#
# 5. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
# 6. Write the answer to your question in a text box underneath the code you used to calculate the answer.

# %%
import pandas as pd

df = pd.read_csv('brain_stroke.csv', encoding='ISO-8859-1')

df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
gender_counts = pd.Series({
    "Male": ((df['gender'] == 'Male') & (df['stroke'] == 1)).sum(),
     "Female": ((df['gender'] == 'Female') & (df['stroke'] == 1)).sum()})

gender_counts.plot(kind='pie')
# Out:
# <Axes: >

# %%
df['bmi'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['avg_glucose_level'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
smokingCounts = pd.Series({
    "Smoker": ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).sum(),
    "NonSmoker (Stroke)": ((df['smoking_status'] == 'never smoked') & (df['stroke'] == 1)).sum()
})

smokingCounts.plot(kind='pie', autopct='%d', ylabel='', title='Smokers vs Non-Smokers (with Stroke)')
# Out:
# <Axes: title={'center': 'Smokers vs Non-Smokers (with Stroke)'}>

# %%
Yes, females tend to have a higher chance of stroke.
Yes, strokes are more common over the age of 35
Yes, it is more common for someone with a BMI of 25%+ to have a stroke.
No, the average glucose is around 70 -140 and that seems to be within normal range for most stroke patients.
Yes, smokers had a much higher risk of strokes than non smokers.
